# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import sqlite3
import sqlalchemy
from sqlalchemy import create_engine

# %%
file_path = "../../datasets/airports.csv"

# %%
df = pd.read_csv(file_path, names=['AirportID', 'Airport', 'City', 'State'])

# %%
df
# Out:
#      AirportID Airport                       City State
# 0        12892     LAX            Los Angeles, CA    CA
# 1        12889     LAS              Las Vegas, NV    NV
# 2        11995     GSO  Greensboro/High Point, NC    NC
# 3        10469     AZO              Kalamazoo, MI    MI
# 4        14057     PDX               Portland, OR    OR
# ..         ...     ...                        ...   ...
# 389      14534     RIW        Riverton/Lander, WY    WY
# 390      12559     JST              Johnstown, PA    PA
# 391      10275     ALW            Walla Walla, WA    WA
# 392      14303     PUW                Pullman, WA    WA
# 393      15138     TBN      Fort Leonard Wood, MO    MO
#
# [394 rows x 4 columns]

# %%
def split_city(val):
    return val.split(",")[0]

# %%
df['City'] = df.City.apply(split_city)

# %%
df
# Out:
#      AirportID Airport                   City State
# 0        12892     LAX            Los Angeles    CA
# 1        12889     LAS              Las Vegas    NV
# 2        11995     GSO  Greensboro/High Point    NC
# 3        10469     AZO              Kalamazoo    MI
# 4        14057     PDX               Portland    OR
# ..         ...     ...                    ...   ...
# 389      14534     RIW        Riverton/Lander    WY
# 390      12559     JST              Johnstown    PA
# 391      10275     ALW            Walla Walla    WA
# 392      14303     PUW                Pullman    WA
# 393      15138     TBN      Fort Leonard Wood    MO
#
# [394 rows x 4 columns]

# %%
df_airports = pd.read_csv("https://raw.githubusercontent.com/mborsetti/airportsdata/main/airportsdata/airports.csv")

# %%
df_airports
# Out:
#        icao iata                         name          city        subd  \
# 0      00AK  NaN                 Lowell Field  Anchor Point      Alaska
# 1      00AL  NaN                 Epps Airpark       Harvest     Alabama
# 2      00AZ  NaN               Cordes Airport        Cordes     Arizona
# 3      00CA  NaN      Goldstone /Gts/ Airport       Barstow  California
# 4      00CO  NaN                   Cass Field    Briggsdale    Colorado
# ...     ...  ...                          ...           ...         ...
# 28879  ZYTN  TNH    Tonghua Sanyuanpu Airport       Tonghua       Jilin
# 28880  ZYTX  SHE              Taoxian Airport      Shenyang    Liaoning
# 28881  ZYXC  XEN           Xingcheng Air Base           NaN    Liaoning
# 28882  ZYYJ  YNJ  Yanji Chaoyangchuan Airport         Yanji       Jilin
# 28883  ZYYY  NaN      Shenyang Dongta Airport      Shenyang    Liaoning
#
#       country  elevation        lat         lon                   tz
# 0          US        450  59.949200 -151.695999    America/Anchorage
# 1          US        820  34.864799  -86.770302      America/Chicago
# 2          US       3810  34.305599 -112.165001      America/Phoenix
# 3          US       3038  35.350498 -116.888000  America/Los_Angeles
# 4          US       4830  40.622200 -104.344002       America/Denver
# ...       ...        ...        ...         ...                  ...
# 28879      CN       1200  42.253889  125.703333        Asia/Shanghai
# 28880      CN        198  41.639801  123.483002        Asia/Shanghai
# 28881      CN         30  40.580299  120.697998        Asia/Shanghai
# 28882      CN        624  42.882801  129.451004        Asia/Shanghai
# 28883      CN          0  41.784401  123.496002        Asia/Shanghai
#
# [28884 rows x 10 columns]

# %%
airports_final = df.set_index('Airport').join(df_airports.set_index('iata'))[['AirportID', 'City', 'State', 'elevation', 'lat', 'lon']].reset_index().rename({"index":"Airport", "elevation": "Elevation", "lat":"Lat", "lon":"Lon"}, axis=1)

# %%
airports_final
# Out:
#     Airport  AirportID                        City State  Elevation  \
# 0       ABE      10135  Allentown/Bethlehem/Easton    PA      393.0
# 1       ABI      10136                     Abilene    TX     1791.0
# 2       ABQ      10140                 Albuquerque    NM     5355.0
# 3       ABR      10141                    Aberdeen    SD     1302.0
# 4       ABY      10146                      Albany    GA      197.0
# ..      ...        ...                         ...   ...        ...
# 389     XWA      16869                   Williston    ND     2356.0
# 390     YAK      15991                     Yakutat    AK       33.0
# 391     YKM      16101                      Yakima    WA     1099.0
# 392     YNG      16133           Youngstown/Warren    OH     1192.0
# 393     YUM      16218                        Yuma    AZ      213.0
#
#            Lat         Lon
# 0    40.652100  -75.440804
# 1    32.411301  -99.681900
# 2    35.040199 -106.609001
# 3    45.449100  -98.421799
# 4    31.535500  -84.194504
# ..         ...         ...
# 389  48.259833 -103.750500
# 390  59.503300 -139.660004
# 391  46.568199 -120.543999
# 392  41.260700  -80.679100
# 393  32.656601 -114.606003
#
# [394 rows x 7 columns]

# %%
airports_final.to_csv('../../datasets/airports_final.csv', index=False)

# %%
db_path = "../../dbs/delays.db"

# %%
conn = sqlite3.connect(db_path)
conn.execute("DROP TABLE IF EXISTS airport;")

create_query = ''' \
            CREATE TABLE airport
            ( 
                Airport                         VARCHAR, 
                AirportID                       INT,
                City                            VARCHAR,
                State                           VARCHAR,
                Elevation                       REAL,
                Lat                             REAL,
                Lon                             REAL
            );
    '''
conn.execute(create_query)
conn.close()
engine = sqlalchemy.create_engine("sqlite:///"+db_path, echo=False)

# %%
engine = sqlalchemy.create_engine("sqlite:///"+db_path, echo=False)
airports_final.to_sql('airport', con=engine, if_exists='append', index=False)
